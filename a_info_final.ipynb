# %%
import mne                                                              # Librería de python para explorar, visualizar,
mne.set_log_level('WARNING')                                            # y analizar datos neurofisiológicos humanos.
import scipy.io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb                                                    
color = ['green', 'blue','red','cyan', 'magenta', 'yellow','k','w']     # Paleta de colores para diferenciar las ondas

import a_funciones as a_fun                                             # Funciones Alex
import os                                                               # Para importar varios archivos

xlabel = 'Muestra'                                                      # Abscisas
ylabel = 'Amplitud (uV)'                                                # Ordenadas

'''
'o': Círculo.
's': Cuadrado.
'D': Diamante.
'^': Triángulo hacia arriba.
'v': Triángulo hacia abajo.
'>': Triángulo hacia la derecha.
'<': Triángulo hacia la izquierda.
'p': Pentágono.
'H': Hexágono.
'+': Cruz.
'x': X.
'''
# Out:
# "\n'o': Círculo.\n's': Cuadrado.\n'D': Diamante.\n'^': Triángulo hacia arriba.\n'v': Triángulo hacia abajo.\n'>': Triángulo hacia la derecha.\n'<': Triángulo hacia la izquierda.\n'p': Pentágono.\n'H': Hexágono.\n'+': Cruz.\n'x': X.\n"

# %%
resultados_amp = pd.read_csv('./a_results/info_final/resultados_amp.csv', index_col=0, delimiter=';')
resultados_fase = pd.read_csv('./a_results/info_final/resultados_fase.csv', index_col=0, delimiter=';')
resultados_gauss = pd.read_csv('./a_results/info_final/resultados_gauss.csv', index_col=0, delimiter=';')

# %%
#--------------------------------------------------------------
#-- Secuencia de intensificación con variaciones en amplitud --
#--------------------------------------------------------------
#plt.figure(figsize=(30,8))    
plt.figure(figsize=(10,8))                                                                                
axes = plt.gca()                                                    
plt.plot(resultados_amp['secuencia'], resultados_amp['P300S01'], 
    linestyle='-.', marker='o', color='red', label='01',
    markerfacecolor='red', markersize=4) 
plt.plot(resultados_amp['secuencia'], resultados_amp['P300S02'], 
    linestyle='--', marker='>', color='blue', label='02',
    markerfacecolor='blue', markersize=4) 
plt.plot(resultados_amp['secuencia'], resultados_amp['P300S03'], 
    linestyle='-.', marker='o', color='green', label='03',
    markerfacecolor='green', markersize=4) 
plt.plot(resultados_amp['secuencia'], resultados_amp['P300S06'], 
    linestyle='--', marker='>', color='orange', label='04',
    markerfacecolor='orange', markersize=4) 
'''
plt.plot(resultados_amp['secuencia'], resultados_amp['P300S05'], 
    linestyle='-.', marker='o', color='cyan', label='05',
    markerfacecolor='cyan', markersize=4) 
plt.plot(resultados_amp['secuencia'], resultados_amp['P300S06'], 
    linestyle='--', marker='>', color='black', label='06',
    markerfacecolor='black', markersize=4) 
plt.plot(resultados_amp['secuencia'], resultados_amp['P300S07'], 
    linestyle='-.', marker='o', color='brown', label='07',
    markerfacecolor='brown', markersize=4) 
plt.plot(resultados_amp['secuencia'], resultados_amp['P300S08'], 
    linestyle='-.', marker='>', color='magenta', label='08',
    markerfacecolor='magenta', markersize=4) 
'''
axes.set_title('Variaciones en amplitud', fontsize=30)
axes.set_xlabel('Secuencia de intensificación')
# axes.set_xlabel('Secuencia de intensificación de amplitud (µV)')
axes.set_ylabel('Porcentaje de aciertos')
axes.title.set_size(30)
axes.xaxis.label.set_size(15)
axes.yaxis.label.set_size(15)                                  
plt.grid()
plt.legend(loc='lower right',fontsize='xx-large')
plt.savefig("./a_images/resultados_amp.jpg")
plt.show()
#---------------------------------------------------------
#- Secuencia de intensificación con variaciones en fase .-
#---------------------------------------------------------
#plt.figure(figsize=(30,8))    
plt.figure(figsize=(10,8))                                                                                
axes = plt.gca()                                                    
plt.plot(resultados_fase['secuencia'], resultados_fase['P300S01'], 
    linestyle='-.', marker='o', color='red', label='01',
    markerfacecolor='red', markersize=4) 
plt.plot(resultados_fase['secuencia'], resultados_fase['P300S02'], 
    linestyle='--', marker='>', color='blue', label='02',
    markerfacecolor='blue', markersize=4) 
plt.plot(resultados_fase['secuencia'], resultados_fase['P300S03'], 
    linestyle='-.', marker='o', color='green', label='03',
    markerfacecolor='green', markersize=4) 
plt.plot(resultados_fase['secuencia'], resultados_fase['P300S06'], 
    linestyle='--', marker='>', color='orange', label='04',
    markerfacecolor='orange', markersize=4) 
'''
plt.plot(resultados_amp['secuencia'], resultados_amp['P300S05'], 
    linestyle='-.', marker='o', color='cyan', label='05',
    markerfacecolor='cyan', markersize=4) 
plt.plot(resultados_amp['secuencia'], resultados_amp['P300S06'], 
    linestyle='--', marker='>', color='black', label='06',
    markerfacecolor='black', markersize=4) 
plt.plot(resultados_amp['secuencia'], resultados_amp['P300S07'], 
    linestyle='-.', marker='o', color='brown', label='07',
    markerfacecolor='brown', markersize=4) 
plt.plot(resultados_amp['secuencia'], resultados_amp['P300S08'], 
    linestyle='-.', marker='>', color='magenta', label='08',
    markerfacecolor='magenta', markersize=4) 
'''
axes.set_title('Variaciones en fase' , fontsize=10)
axes.set_xlabel('Secuencia de intensificación')
# axes.set_xlabel('Secuencia de intensificación de amplitud (µV)')
axes.set_ylabel('Porcentaje de aciertos')
axes.title.set_size(30)
axes.xaxis.label.set_size(15)
axes.yaxis.label.set_size(15)                                  
plt.grid()
plt.legend(loc='lower right',fontsize='xx-large')
plt.savefig("./a_images/resultados_fase.jpg")
plt.show()
#--------------------------------------------------------------
#--------- Secuencia de intensificación con insersión ---------
#-- de forma de onda gaussiana en reemplazo del ERPTemplate ---
#--------------------------------------------------------------
#plt.figure(figsize=(30,8))    
plt.figure(figsize=(10,8))                                                                                
axes = plt.gca()                                                    
plt.plot(resultados_gauss['secuencia'], resultados_gauss['P300S01'], 
    linestyle='-.', marker='o', color='red', label='01',
    markerfacecolor='red', markersize=4) 
plt.plot(resultados_gauss['secuencia'], resultados_gauss['P300S02'], 
    linestyle='--', marker='>', color='blue', label='02',
    markerfacecolor='blue', markersize=4) 
plt.plot(resultados_gauss['secuencia'], resultados_gauss['P300S03'], 
    linestyle='-.', marker='o', color='green', label='03',
    markerfacecolor='green', markersize=4) 
plt.plot(resultados_gauss['secuencia'], resultados_gauss['P300S06'], 
    linestyle='--', marker='>', color='orange', label='04',
    markerfacecolor='orange', markersize=4) 
'''
plt.plot(resultados_gauss['secuencia'], resultados_gauss['P300S05'], 
    linestyle='-.', marker='o', color='cyan', label='05',
    markerfacecolor='cyan', markersize=4) 
plt.plot(resultados_gauss['secuencia'], resultados_gauss['P300S06'], 
    linestyle='--', marker='>', color='black', label='06',
    markerfacecolor='black', markersize=4) 
plt.plot(resultados_gauss['secuencia'], resultados_gauss['P300S07'], 
    linestyle='-.', marker='o', color='brown', label='07',
    markerfacecolor='brown', markersize=4) 
plt.plot(resultados_gauss['secuencia'], resultados_gauss['P300S08'], 
    linestyle='-.', marker='>', color='magenta', label='08',
    markerfacecolor='magenta', markersize=4) 
'''
axes.set_title('Insersión de forma de onda gaussiana')
axes.set_xlabel('Secuencia de intensificación')
# axes.set_xlabel('Secuencia de intensificación de amplitud (µV)')
axes.set_ylabel('Porcentaje de aciertos')
axes.title.set_size(30)
axes.xaxis.label.set_size(15)
axes.yaxis.label.set_size(15)                                  
plt.grid()
plt.legend(loc='lower right',fontsize='xx-large')
plt.savefig("./a_images/resultados_gauss.jpg")
plt.show()

# %%
'o': Círculo.
's': Cuadrado.
'D': Diamante.
'^': Triángulo hacia arriba.
'v': Triángulo hacia abajo.
'>': Triángulo hacia la derecha.
'<': Triángulo hacia la izquierda.
'p': Pentágono.
'H': Hexágono.
'+': Cruz.
'x': X.
